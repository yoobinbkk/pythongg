# %% [markdown]
# ### 1. Series 의 plot()

# %%
# %matplotlib inline

from matplotlib import font_manager, rc
import matplotlib.pyplot as plt

plt.rcParams['axes.unicode_minus']=False  # 추가설정 : 폰트를 변경하면 -표시가 ㅁ으로 변경되기에 '-'를 변경하지 않도록 지정
rc('font', family='Malgun Gothic')

# %%
from pandas import Series

# %%
# 판다스 그래프 : Series의 plot() 
s=Series([1.5, 2.3, 0.9], index=['no1','no2','no3'])
s

s.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
s=Series([1.5, 2.3, 0.9], index=['no1','no2','no3'])
splot = s.plot(kind='bar')
splot.set_xlabel('데이터')
splot.set_ylabel('값')
splot.set_title('샘플데이터')
# Out:
# Text(0.5, 1.0, '샘플데이터')

# %% [markdown]
# ## 2. DataFrame 그래프

# %%
from pandas import DataFrame
import numpy as np

# 데이타프레임에서 시각화 작업
df=DataFrame(np.random.randn(10, 4),    # 난수 10개를 4번
             columns=['level','step','cnt','temp'], 
             index=np.arange(0,100,10))     # np.arange(0,100,10)

df
# Out:
#        level      step       cnt      temp
# 0  -0.730879 -1.708365  2.017071 -0.700576
# 10 -0.180263  2.785574 -0.844723  1.327523
# 20 -0.539083  1.005481  0.112294  1.238846
# 30  1.001921  0.592503  0.146753 -0.014048
# 40  0.573309  2.135719 -1.106301  0.487707
# 50 -0.675685  0.729949  0.596169 -0.167952
# 60  0.012730  0.830000 -0.006249 -1.020498
# 70  1.108635  0.046109 -1.668551  0.491633
# 80 -1.182904 -0.488917 -0.430754 -0.094233
# 90  0.797401 -0.463068  2.402390  1.311966

# %%
df.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# [참고] 데이타사이언스스쿨 > Pandas의 시각화 기능
#
# https://datascienceschool.net/view-notebook/372443a5d90a46429c6459bba8b4342c/
